# %% [markdown]
# ## Loss function 손실함수

# %%
from IPython.display import Image

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\2.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\3.png")

# %% [markdown]
# Linear Layer Parameter = {W,b}
#
# 입력: Linear Layer 파라미터
# 출력: 지금 이 Linear Layer가 주어지면 Loss 값은 얼마니?
#
# 목표 = 결국 우리는 어떤 파라미터를 가져야지만 머릿속에 있는 함수를 잘 모사할까? 또한 이 Loss Function를 가지고 우리는 어떻게 Neuarl Network 또는 Linear Layer를 학습시킬것인가

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\4.png")

# %% [markdown]
# Euclidean Distance = L2 라고도 표현
# L1 은 절댓값
#
# 두개의 벡터가 주어진 상태
#
# 차원이 커질수록 값이 커짐. 따라서 RMSE(평균값)을 구함

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\5.png")

# %% [markdown]
# Error = (y - y hat)
#
# square = (y - y hat) 제곱

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\6.png")

# %% [markdown]
# 1/n 빼도 비교 결과가 바뀌지않아 1/n 빼도 괜찮음
#
# MSE = 두 샘플간의 거리 로 많이 사용

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\7.png")

# %% [markdown]
# Loss 함수를 활용해서 어떤 파리미터가 Loss 함수를 최소화하는지 찾아낼수있다.
#
# 결과: Linear Layer 파라미터를 바꿔가면서 Loss를 최소화해야한다. 어떻게 바꾸는지는 다음 강의에..
