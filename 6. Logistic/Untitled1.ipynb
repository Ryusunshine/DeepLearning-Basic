# %%
from IPython.display import Image
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\777.png")

# %% [markdown]
# * 먼저 Linear Layer를 먼저 통과시키고난다음 시그모이드를 통과시킨다.
# * |x 1:N| = (N,n)
# * |w| = (n,m)
# * b = (m,)
#
#
# * Loss 함수에도 놓어서 Loss가 최소화하도록 gradient descent를 수행할거임
#
#
# * 우리가 원하는거는 loss를 minimize하는 세타를 찾는거이다.그걸 하기위해서 loss(w,b)를 각각 w와 b로 미분하고 learning rate 를 곱해서 빼주면 새로운 w와b로 업데이트할수있음.이걸 iterative하게 수렴할때까지 진행하면 f세타 = 시그모이드(x 1:n * W +b)값을 구할수있다.
