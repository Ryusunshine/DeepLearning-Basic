# %%
from IPython.display import Image
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\111.png")

# %% [markdown]
# * 숫자2가 적힌 사진을 입력했을때 2라고 인식하게 만드는 함수를 만들고 싶은거
#
# * Linear regression은 True/False 문제를 해결못해서 로지스틱으로 해결해야한다.

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\222.png")

# %% [markdown]
# P(y|x) = x가 주어졌을때 y가 일어날 확률

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\333.png")

# %% [markdown]
# y = 1 = True 이면
# y_hat도 1에 근사해야함

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\555.png")

# %% [markdown]
# * yi가 0 또는 1로 된 함수의 m차원
# * xi는 실수의 집합의 n차원
# * yi_hat은 [0또는 1의] m차원이다
#
# * yi의 transpose 된 값과 log y_hat의 결과값이 곱해지면 yi에 있는 1만 살아남아 yi에 있는 0.9와 곱해져 결과값이 로그0.9가 나온다.
#
# * 1-yi_hat의 transpose에 1이 있는 값과 1-yi_hat의 로그 값이 곱해지면 0.9, 0.6,0.9 값이 나와 log0.9 + log0.6 + log 0.7 이라는 결과값이 나온다.
#
# * -1/N 뒤의 값은 maximize 해야한다.

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\666.png")
