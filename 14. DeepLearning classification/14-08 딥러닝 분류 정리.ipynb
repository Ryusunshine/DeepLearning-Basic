# %% [markdown]
# ### Wrap-up

# %%
from IPython.display import Image

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\1000.png")

# %% [markdown]
# * Target(y값)
#
# regression은 real number (실수)
#
# ex) 몸무게-키의 관계
#
# class =클래스가 주어짐. 클래스가 2개. 결과값은 True or False
#
# * Final activation function (활성화함수)
#
# regressino 은 아무것도 안해줌.
#
# binary classification은 sigmoid
#
# multi-class classficaiton은 softmax나 log-softmax
#
# * Loss function
#
# Regression은 MSE Loss
#
# Binary classification은 BCE Loss
#
# Multi-class classification은 CrossEntropy(NLL) Loss
#
# ### 일단외워!!!!!외우래!!!

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\55.png")

# %% [markdown]
# 정답을 one-hot vector로 활용을 하게 되고 one-hot vector와 classifier가 뱉어낸 분포(y_hat)을 비교해서 그 차이가 작아지도록 loss를 통해서 최적화한다.  one-hot vector를 label로 저장할때는 one-hot의 인덱스(class number)만 저장하면 된다. 고양이가 0이고, 호랑이가1, 개가 2, 늑대가 3이라고 지정되잇을때 yi = 0이라고 저장하고 이건 자연스럽게 one-hot vector로 치환하면 1 0 0 0이 되는것이다. 만약 yi = 2이면 one-hot vector는 0010이 된다. 따라서 값을 저장할때는 long tensor(인덱스)로 저장된다.

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\56.png")

# %% [markdown]
# classifier는 확률분포를 뜻한다. classifier같은 경우에는 예측해야하는값이 discrete하다. target(y값)이 categorical value라서 값이 딱딱 떨어지니깐 다양한 평가를 수행할수있음. confusion matrix를 통해 각 class별 어디가 부족하고 취약한지 파악하고 자료들을 더 모아 보완하는등 대처할수있다.
