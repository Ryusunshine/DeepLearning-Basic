# %%
from IPython.display import Image

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\3.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\4.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\5.png")

# %% [markdown]
# 클래스별로 확률값을 뱉어낸다.

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\6.png")

# %% [markdown]
# 항목별로 확률값을 뱉어낸다

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\7.png")

# %% [markdown]
#  시그모이드 대신 softmax를 사용한다

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\8.png")

# %% [markdown]
# 회귀문제랑 분류문제에 따라 사용하는 함수가 다르다
# bInary 문제는 sigmoid쓰고 일반문제는 softmax를 맨마지막에 사용해서 구현한다. 그럼 우리는 확률값을 구할수있다

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\9.png")

# %% [markdown]
# 원핫인코딩 = 정답에만 1이 있고 나머지는 0인 벡터
#
# 그래서 소프트맥스는 확률분포형태로 나오게됨.확률값 다 합치면 1됨.

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\11.png")

# %% [markdown]
# regression은 mse
# classification은 cross entropy 사용한다는걸 외워

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\12.png")

# %% [markdown]
# softmax에 log붙인 log-softmax는 NLL(negative log likelihood)를 쓴다

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\13.png")

# %% [markdown]
# P(y = y|x = x)
# 랜덤variable X라는 거에 어떤 실제x라는 값(이미지,텍스트,음성)이 주어졌을때 y variable값에 y확률값을 return한다.

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\20.png")

# %% [markdown]
# 만약 제품화 & 배포의 정확도를 파악한다고할때 제품화가 99%이고 배포의 정확도는 1%이라고할때 accuracy을 제대로 파악하지못하는것.
# 해결점 = confusion matrix

# %% [markdown]
# ### Confusion Matrix - 혼동행렬

# %% [markdown]
# 실제 서비스나 배포를 염두에 두고 있는 머신러닝 프로젝트를 수행중이라면, 모델을 배포하기에 앞서 면밀하게 모델의 성능을 검토하는 작업을 수행해야 합니다. 이번 장에는 다중 클래스 분류multi class classification의 결과 분석을 위한 방법인 혼동 행렬confusion matrix에 대해서 소개하도록 하겠습니다.

# %% [markdown]
# ### 혼동행렬

# %% [markdown]
# 혼동 행렬
# 보통 분류 문제는 정확도accuracy를 통해서 모델의 성능을 평가할 수 있습니다. 하지만 서비스를 위해서는 단순히 정확도만 살펴보기보단, 어떤 케이스에서 모델이 약하고 쉽게 틀릴 수 있는지 파악할 수 있어야 합니다. 또한 모델의 단점에 대한 면밀한 분석이 있어야지만, 이후 모델의 개선에 있어서도 올바른 방향으로 효율적인 개선을 수행할 수 있을 것입니다. 이런 의미에서 혼동 행렬confusion matrix은 매우 유용하게 활용될 수 있습니다.
#
# 다음 그림은 MNIST 분류에 대해서 테스트셋 예측 결과에 대해 혼동 행렬을 구성한 표입니다.

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\21.png")

# %% [markdown]
# 행렬 표의 대각 성분은 정답을 맞춘 갯수를 의미합니다. 또한 표에서 ‘true_3’ 행의 ‘pred_2’ 열에 위치한 값이 6으로 되어 있는데요. 이것은 실제 3이 정답인데, 2로 예측해서 틀린 샘플의 숫자가 6개라는 의미입니다.
#
# 사실 이미 테스트셋 기준 정확도 98%가 넘는 상황이므로, 대부분의 샘플들이 올바르게 예측되고 있는 것을 볼 수 있습니다. 다만 그럼에도 불구하고 일부 틀리는 샘플들은 존재하고 있는데요. 특히, 그림에서 빨간색 네모로 강조된 영역들은 모델이 잘 예측하지 못하는 케이스를 가리킵니다.
#
# 예를 들어 ‘true_4’ 행의 ‘pred_9’ 열의 경우에는, 정답이 4인데 예측을 9라고 해서 틀린 경우가 12개였음을 의미하는데요. 실제로 4와 9는 비슷한 모양을 가지고 있으므로 헷갈릴 여지가 있어 보입니다. 따라서 만약 배포를 염두에 두고 모델 개선을 하고자 한다면, 4와 9에 대한 데이터를 더 모으거나, 4와 9를 구별하기 위한 추가적인 조치를 고민해야겠지요. 이후에 그렇게 모든 영역에서 쏠림 없이 용납되는 수준의 오류만 보인다면, 배포 준비가 되었다고 판단할 수 있을 것입니다.

# %% [markdown]
# 성능이 98%라도 취약한 점을 보고 분석해야함
# true_0 = 실제0
# pred_0 = 0이라고 추측
