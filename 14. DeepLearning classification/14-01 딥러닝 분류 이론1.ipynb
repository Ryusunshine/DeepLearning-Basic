# %%
from IPython.display import Image

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\42.png")

# %% [markdown]
# 로지스틱 regression은 선형회귀(linear regression)에서 시그모이드를 맨마지막에 추가해줌으로써 0에서 1사이의 출력값을 제한하게되고 binary classification을 수행하였음.
# loss 계산할때는 BCELoss를 썼었음

# %% [markdown]
# ### softmax 함수 - classification
# 인공신경망이 결과로 내놓은 K개의 클래스를 확률처럼 해석하도록 만들어 준다. 함수의 범위가 [0, 1]이기 때문이다. 따라서 output 노드 바로 뒤에 부착된다.

# %% [markdown]
# ### logit
# logit은 이진 분류 문제(binary classification)이다. y가 C1 으로 분류될 확률이라면 C2으로 분류될 확률은 1-y이다. (확률의 총합은 1이고, 이진 분류이기 때문). 확률(odds)에 log을 씌운값이다.
# * logit 변환은 [0, 1]의 범위를 가지는 확률을 [-∞, ∞]로 바꿔주는 변환이다. 따라서 예측값(y)과 예측값을 만들어내는 특성값(x)의 관계를 선형 관계(y = wx+b)로 만들 수 있게 한다. y의 범위는 [0, 1]이고, 특성값 x의 범위는 [-∞, ∞]이므로 관계를 말할 수 없지만 logit 변환을 사용하면 두 값의 관계를 말할 수 있고, 이로 인해 로지스틱 회귀식을 사용할 수 있게 된다
#
# 그러나 분류를 하는 딥러닝에서는 확률화되지 않은 예측 결과를 logit이라고 한다. 확률값을 계산하지 않고 layer를 거쳐 나온 산출물을 그대로 다음 layer에 넘길 때 사용한다. 다시 말하면, logit은 신경망의 최종 레이어가 내놓는 확률값이 아닌 결과이고, 결과값의 범위가 [-∞, ∞]이다. 따라서 양수인지, 음수인지에 따라서 클래스를 구분할 수 있다(이진 분류). 다중 분류 문제에서 logit은 보통 Softmax 함수의 입력으로 사용된다. Softmax 함수는 신경망의 결과를 확률로 바꿔준다.

# %% [markdown]
# ### BCE Loss
#
# * 만약 class 가 2개인 binary case인 경우에는 BCELoss를 사용하시는 것이 좋습니다.
#
# torch.nn.BCELoss(weight=None, size_average=None, reduce=None, reduction='mean')
# 하지만, BCELoss에서는 CrossEntropyLoss와 같이 softmax를 포함한 것이 아닌, Cross Entropy만 구합니다. 따라서, 이 loss를 사용하는 경우엔 softmax 또는 다른 activation function을 따로 적용해주어야 합니다.
#
# 이 경우에는 binary class이기 때문에 input과 target 모두 (minibatch, ) shape을 갖습니다. 각 minibatch 마다 input 값의 range는 [0,1]이 될 것이고, target 값은 0 또는 1이 될 것입니다.
#
# 실제 사용할 때에는 다음과 같이 작성합니다.
#
# import torch.nn as nn
#
# criterion = nn.BCELoss()
# ...
# loss = criterion(nn.Sigmoid(input), target) # 또는 nn.Softmax(input)

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\43.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\44.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\45.png")

# %% [markdown]
# 로지스틱 regression은 선형회귀(linear regression)에서 시그모이드를 맨마지막에 추가해줌으로써 0에서 1사이의 출력값을 제한하게되고 binary classification을 수행하였음.
# loss 계산할때는 BCELoss를 썼었음

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\46.png")

# %% [markdown]
# 로지스틱 regression사용했던 model을 DNN에 시그모이드 실어서 바꿔끼우면 똑같이 최적화가능

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\47.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\48.png")

# %% [markdown]
# False Alarm : 정상인데 누출이라고 뜨는거(원자력발전소는 이렇게 가져가야함)

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\49.png")

# %% [markdown]
# * Precision : positive 라고 예측한것중에 실제 맞은것(내가 예측한것중에서 얼마나 맞앗냐?)
# * Recall(회수율)  : 실제 positive인것중에 내가 맞춘것(실제 누출한것중에서 얼마나 회수햇어?)- 원자력발전소는 recall이 좋아야함
#
# 문제는 실전에 가면 헷갈림 - 면접에서 물어볼수있음

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\50.png")

# %% [markdown]
# 결국 precision과 recall  둘다 좋은게 좋음
# 합친게 = F1 Score

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\52.png")

# %% [markdown]
# AUROC(Area Under Receiver operating characteristic) = 사각형 넓이에서 어느정도의 비율이 되는가
#
# 샘플들의 분포가 잘 떨어져있는지 붙어있는지 파악을 해서 이 classifier가 robust하다 를 파악할수있음

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\53.png")
