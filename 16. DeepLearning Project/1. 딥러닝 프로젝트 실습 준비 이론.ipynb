# %%
from IPython.display import Image

# %% [markdown]
# ### 코드 짜는 순서

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\0.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\11.png")

# %% [markdown]
# 실수야?
# * Yes -> MSE Loss
# * No ->
#
# 그럼 Binary 야?
# * Yes -> Sigmoid & BCE Loss
# * No -> Softmax & Cross Entropy

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\12.png")

# %% [markdown]
# ReLU 쓸거야? LeakyReLU 쓸꺼야?
# => 두개 차이 별로 없음
#
# Batch norm or Dropout?
# => 이 두개도 차이 별로없음
#
# ### 쌤 조언
# 일단 기본적인 형태를 만들고 baseline까는게 우선!!
# baseline 구성하고나면 성능이 나오니깐 성능이 안좋아지면 다시 기본으로 돌아와서 다시 짜고 좋으면 나아가구 점진적으로 성능을 개선한다.

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\13.png")

# %% [markdown]
# 네트워크 구성하고나면 하이퍼 파라미터 튜닝 엄청해야함. 그러나 test set 대상으로 튜닝을 진행하면 안됨!

# %% [markdown]
# ## 정리 및 복습

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\14.png")

# %% [markdown]
# ## 이 그림 외워!! 너가 바로 말할수있어야해!

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\15.png")

# %% [markdown]
# Trainer 클래스를 만들건데 이 Trainer는 model 클래스를 가지고 있을거고 training과 validation 함수를 들고있을거임.
#
# train set을 받아와서 model 에 넣어주면 training 함수에서 iteration 돌면서 학습이 되고 끝나면 valid set이 validation함수에 들어가서 iteration이 돌거다. 나온 결과값을 모아서 그중에서 bestmodel 저장

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\16.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\17.png")

# %% [markdown]
# Architecture 구성
#
# Block 함수 만들어서 사용반복
# 결과값으로 나온 y_hat에는 확률값이 들어있을거고 y_hat과 y를 비교하기위해 NLL Loss를 써서  실제 Loss를 구할거고 Loss를 최소화하도록  gradient descent 를 진행하면 우리가 원하는 파라미터를 찾을수있따. 그럼 우리는 우리 머릿속에 있는 손글씨를 인식하는 함수를 근사할수있다.

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\18.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\19.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\20.png")
