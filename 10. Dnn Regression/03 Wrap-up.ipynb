# %% [markdown]
# ### 정리

# %%
from IPython.display import Image

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\10.png")

# %% [markdown]
# 차이점
# * DNN은 Loss가 볼록하지 않고 복잡함. 따라서 최적화에 어려움이 있을수있음. 하지만 여전히 같은 방법을 통해 최적화

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\11.png")

# %% [markdown]
# * backpropagation은 DNN을 학습시키기 위한 방법. 우리는 gradient descent 하기 위해서 미분해야해서 각 파라미터를 가지고 미분을 해줌.
#
# * 입력에 가까운  layer일수록 gradient vanishing이 발생할수있음. ReLu나 Leaky Relu를 통해 어느정도 해결가능.
