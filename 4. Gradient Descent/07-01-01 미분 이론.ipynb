# %% [markdown]
# ### Gradient Descent

# %%
from IPython.display import Image

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\10.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\12.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\13.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\14.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\15.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\16.png")
