# %% [markdown]
# ### Wrap -up

# %%
from IPython.display import Image

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\71.png")

# %% [markdown]
# 우리는 어떤 함수를 근사하고싶은데 함수에 들어가는 세타는 함수가 어떻게 동작하는지 정의해서 우리는 이 파라미터를 잘 조절함으로써 실제 x를 넣었을때 원하는 y값을 얻을수있다. 그 방법중에 하나가 손실함수를 도입을 해서 이 손실함수를 최소화하도록 파라미터를 조절하자 이다.
# 하는 방법은 손실함수는 Loss를 세타로 미분을 해서 gradient를 얻고, loss를 낮추는 방향을 알수있다

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\72.png")
