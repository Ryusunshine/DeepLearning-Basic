# %% [markdown]
# ### Learning Rate

# %%
from IPython.display import Image

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\41.png")

# %% [markdown]
# Learning rate가 크면은 gradient가 많이 움직이며
# Learning rate가 작으면은 gradient가 조금씩 움직인다.

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\42.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\43.png")

# %% [markdown]
# 하이퍼 파라미터: 모델 성능에 영향을 끼치지만, 데이터를 통해 학습 할 수 없는 파라미터
