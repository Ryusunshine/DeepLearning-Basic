# %% [markdown]
# ### 편미분

# %%
from IPython.display import Image

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\21.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\22.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\23.png")

# %% [markdown]
# *******x,y,z축 위에 점이 있을텐데 그때 그 점의 x축에 대한 기울기

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\24.png")

# %% [markdown]
# gradient = 미분한 벡터
#
# 벡터 = 방향

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\25.png")

# %% [markdown]
# x와y로 미분하면 x축과 y축을 놓고 봐야하니깐 '방향'성을 띄고 방향을 가지는 형태가 됨

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\26.png")

# %% [markdown]
# 입력은 n차원인데 출력은 m차원
#
# f는 1부터 m까지 있고 x는 1부터 n까지있음
#
# 그럼 경우의수는 nXm 개고 미분하면 행렬이 나옴

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\27.png")

# %% [markdown]
# 로스함수를 최소화하는 파라미터를 찾을건데 로스라는 스칼라값을 행렬 또는 벡터로 미분하여 최소값을 찾을것이다.
